# %% [markdown]
# # CX4240 HW1
# Author: George Duncan

# %%
from IPython.display import Image
Image("HW1p1.png")

# %%
from IPython.display import Image
Image("HW1p2.png")

# %%
from IPython.display import Image
Image("HW1p3.png")

# %%
from IPython.display import Image
Image("HW1p4.png")
